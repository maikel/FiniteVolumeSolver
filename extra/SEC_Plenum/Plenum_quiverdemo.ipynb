# %%
import yt
import os
import numpy as np
import matplotlib.pyplot as plt

plot_string = "quiver"
dataPath = "/home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum/"
plenum_number = 0

def loadQuiverData(plotfile):
  ds = yt.load(plotfile)
  ad = ds.all_data()
  current_time = ds.current_time
  rho = np.array(ad.index.grids[0]['Density'])
  mom0 = np.array(ad.index.grids[0]['Momentum_0'])
  mom1 = np.array(ad.index.grids[0]['Momentum_1'])
  mom0 = np.squeeze( mom0 )
  mom1 = np.squeeze( mom1 )
  rho = np.squeeze( rho )
  return mom0, mom1, rho, current_time

def PrintProgress(i, plotfiles):
  ny = len(plotfiles)
  progress = int(100.0 * float(i) / (ny - 1))
  print('[{:3d}%] Reading plotfile {}'.format(progress, plotfiles[i]))

yt.funcs.mylog.setLevel(50)
output_dir = dataPath+'/Plotfiles/Plenum%i'%(plenum_number)

dirs = os.listdir(output_dir)
plotfiles = ['{}/{}'.format(output_dir, plt) for plt in dirs]
list.sort(plotfiles)
plotfiles = plotfiles[:]
# print(plotfiles)

ds = yt.load(plotfiles[0])
ad = ds.all_data()
LeftEgdes = ad.index.grids[0].LeftEdge
RightEdges = ad.index.grids[-1].RightEdge

m0, m1, rho, current_time = loadQuiverData(plotfiles[0])
PrintProgress(0, plotfiles)

nx = m0.shape
ny = 100 # len(plotfiles)


ts = np.zeros((ny,1))
ts[0] = ds.current_time
mom0 = np.zeros(shape=(*nx, ny))
mom0[:,:,0] = m0
mom1 = np.zeros_like(mom0)
mom1[:,:,0] = m1
density = np.zeros_like(mom0)
density[:,:,0] = rho

output_path = dataPath+"Plotfiles/Plenum%i_%s/"%(plenum_number, plot_string)
if not os.path.exists(output_path):
  os.makedirs(output_path)

for i in range(1,ny):
   PrintProgress(i, plotfiles)
   m0, m1, rho, current_time = loadQuiverData(plotfiles[i])
   ts[i] = current_time
   mom0[:,:,i] = m0
   mom1[:,:,i] = m1
   density[:,:,i] = rho
# Out:
# [  0%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000000
# [  0%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000008
# [  0%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000017
# [  1%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000027
# [  1%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000037
# [  1%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000047
# [  2%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000057
# [  2%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000067
# [  2%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000077
# [  3%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000087
# [  3%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000097
# [  3%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000107
# [  4%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000117
# [  4%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000127
# [  4%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000137
# [  5%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000147
# [  5%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000158
# [  5%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000169
# [  6%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000180
# [  6%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000191
# [  6%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000202
# [  7%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000213
# [  7%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000224
# [  7%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000235
# [  8%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000247
# [  8%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000259
# [  8%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000271
# [  9%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000283
# [  9%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000295
# [  9%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000307
# [ 10%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000320
# [ 10%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000334
# [ 10%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000348
# [ 11%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000362
# [ 11%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000376
# [ 11%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000391
# [ 12%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000406
# [ 12%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000422
# [ 12%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000439
# [ 13%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000456
# [ 13%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000474
# [ 13%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000492
# [ 14%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000511
# [ 14%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000530
# [ 14%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000550
# [ 15%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000570
# [ 15%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000590
# [ 15%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000610
# [ 16%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000630
# [ 16%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000649
# [ 16%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000668
# [ 17%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000686
# [ 17%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000703
# [ 17%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000719
# [ 18%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000735
# [ 18%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000751
# [ 18%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000767
# [ 19%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000782
# [ 19%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000798
# [ 19%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000814
# [ 20%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000831
# [ 20%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000849
# [ 20%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000867
# [ 21%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000885
# [ 21%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000903
# [ 21%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000921
# [ 22%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000938
# [ 22%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000955
# [ 22%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000971
# [ 23%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000000986
# [ 23%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001000
# [ 23%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001014
# [ 24%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001028
# [ 24%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001041
# [ 24%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001054
# [ 25%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001067
# [ 25%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001080
# [ 25%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001093
# [ 26%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001107
# [ 26%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001121
# [ 26%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001135
# [ 27%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001149
# [ 27%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001164
# [ 27%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001180
# [ 28%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001196
# [ 28%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001212
# [ 28%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001228
# [ 29%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001244
# [ 29%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001260
# [ 29%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001276
# [ 30%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001292
# [ 30%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001308
# [ 30%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001323
# [ 31%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001338
# [ 31%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001352
# [ 31%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001366
# [ 32%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001380
# [ 32%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001394
# [ 32%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001408
# [ 33%] Reading plotfile /home/christian/FVS_develop/FiniteVolumeSolver/build_Release_2d_EB/SEC_Plenum//Plotfiles/Plenum0/plt000001422

# %%
def plotQuiver(plotfile, plot_string, mom0, mom1, density, current_time):
  fig, ax = plt.subplots(figsize=(10,10))
  x = np.linspace(LeftEgdes[0], RightEdges[0], num=mom0.shape[0], endpoint=True)
  y = np.linspace(LeftEgdes[1], RightEdges[1], num=mom1.shape[1], endpoint=True)
  ux = mom0 / density
  uy = mom1 / density

  X,Y = np.meshgrid(x,y)

  skip = 5
  scale = 1.0
  Q = ax.quiver(ux[::skip, ::skip], uy[::skip, ::skip], mom0[::skip, ::skip], 
        scale = scale, units='x', pivot='mid')
  cbar = fig.colorbar(Q)
  cbar.set_label("Momenttum0")
  ax.quiverkey(Q, 0.9, 0.9, 1, r'$1 \frac{m}{s}$', labelpos='E', coordinates='figure')
  ax.set(title="time = %2.6f"%current_time)

  #locs, labels = plt.xticks()
  #newlabels = np.linspace(LeftEgdes[0], RightEdges[0], num=len(labels))
  #ax.set_xticklabels( ["%.2f" % number for number in newlabels] )

  #locs, labels = plt.yticks()
  #newlabels = np.linspace(LeftEgdes[1], RightEdges[1], num=len(labels))
  #ax.set_yticklabels( ["%.2f" % number for number in newlabels] )


  fig.savefig(output_path+plot_string+"_"+plotfile.split("/")[-1]+".png", bbox='tight' )
  fig.clf()
  plt.close(fig)

for i in range(0, ny):
   plotQuiver(plotfiles[i], plot_string, mom0[:,:,i].T, mom1[:,:,i].T, density[:,:,i].T, ts[i])
